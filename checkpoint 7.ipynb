# %% [markdown]
# Checkpoint Objective
#
# Decision Trees & Random Forests
#
# We are going to predict once again if a passenger on the Titanic is going to survive. This time  using decision trees and random forests:

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier

# %%
data = pd.read_csv('Titanic-Dataset.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data["Age"].fillna(data["Age"].median(),inplace=True)

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data["Cabin"].value_counts()
# Out:
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: Cabin, Length: 147, dtype: int64

# %%
data["Cabin"]=data["Cabin"].str[0]

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data["Cabin"].value_counts()
# Out:
# C    59
# B    47
# D    33
# E    32
# A    15
# F    13
# G     4
# T     1
# Name: Cabin, dtype: int64

# %%
data["Cabin"].fillna(data["Cabin"].mode()[0],inplace=True)

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       2
# dtype: int64

# %%
data["Embarked"].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
data["Embarked"].fillna(data["Embarked"].mode()[0],inplace=True)

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data=data.drop("Name",axis=1)
data=data.drop("Ticket",axis=1)

# %%
data
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin  \
# 0              1         0       3    male  22.0      1      0   7.2500     C
# 1              2         1       1  female  38.0      1      0  71.2833     C
# 2              3         1       3  female  26.0      0      0   7.9250     C
# 3              4         1       1  female  35.0      1      0  53.1000     C
# 4              5         0       3    male  35.0      0      0   8.0500     C
# ..           ...       ...     ...     ...   ...    ...    ...      ...   ...
# 886          887         0       2    male  27.0      0      0  13.0000     C
# 887          888         1       1  female  19.0      0      0  30.0000     B
# 888          889         0       3  female  28.0      1      2  23.4500     C
# 889          890         1       1    male  26.0      0      0  30.0000     C
# 890          891         0       3    male  32.0      0      0   7.7500     C
#
#     Embarked
# 0          S
# ...

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
for column in data.columns:
   if data[column].dtype == object:
     le=LabelEncoder()
   data[column] = le.fit_transform(data[column])

# %% [markdown]
# 1. Read your Titanic dataset as usual: Create a training set and a testing set then apply decision tree.

# %%
features = data[['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']]
target = data['Survived']

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
tree_classifier = DecisionTreeClassifier(random_state=42)
tree_classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %% [markdown]
# 2. Plot your decision tree and try to read the tree branches and conclude a prediction manually.

# %%
plt.figure(figsize=(35, 30))
plot_tree(tree_classifier, filled=True ,class_names=['Did not survive', 'Survived'])
plt.show()

# %% [markdown]
# 3. Change the decision tree parameters(at least two parameters).

# %%
tree_classifier = DecisionTreeClassifier(max_depth=5, min_samples_split=5, random_state=42)
tree_classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_split=5, random_state=42)

# %% [markdown]
# 4. Calculate the new accuracy and compare it with the previous results.

# %%
y_pred_tree = tree_classifier.predict(X_test)

# Calculate accuracy
accuracy_tree = accuracy_score(y_test, y_pred_tree)
print(f"Decision Tree Accuracy: {accuracy_tree:.2f}")
# Out:
# Decision Tree Accuracy: 0.80

# %% [markdown]
# 5. Use a random forest then change the number of estimators.

# %%
forest_classifier = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the random forest on the training data
forest_classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
forest_classifier = RandomForestClassifier(n_estimators=200, random_state=42)
forest_classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200, random_state=42)

# %% [markdown]
# 6. Calculate the new accuracy and compare it with the previous result.

# %%
y_pred_forest = forest_classifier.predict(X_test)

# Calculate accuracy
accuracy_forest = accuracy_score(y_test, y_pred_forest)
print(f"Random Forest Accuracy: {accuracy_forest:.2f}")
# Out:
# Random Forest Accuracy: 0.81

# %% [markdown]
# the Random Forest model outperformed the Decision Tree model slightly. However, the difference in accuracy between the two models is not extraordinary.
